# %%
def is_odd(y):
	# 
	if y % 4 == 0 and (y % 100 != 0 or y % 400 == 0):
		return True
	else:
		return False
is_odd(3)
# Out:
# False

# %%
def is_odd(y):
	# 
	if y % 4 == 0 and (y % 100 != 0 or y % 400 == 0):
	  return True
	# else:
	#   return False
is_odd(3)

# %%
# รับค่า ชื่อ นามสกุล เพศ อายุ และ แสดงผล
name = "อัครพล"
lastname = "พิกุลศรี"
s = "ชาย"
age = "19 ปี"

print("ชื่อ-นามสกุล",name, lastname) 
print("เพศ",s)
print("อายุ",age)
# Out:
# ชื่อ-นามสกุล อัครพล พิกุลศรี
# เพศ ชาย
# อายุ 19 ปี

# %%
lang = "Python"
version = 3.6
print("%s langeuage" % lang)
print("Version %f" % version)
print("%d" % 123)
print("%s %f %d" % (lang, version, 123))
# Out:
# Python langeuage
# Version 3.600000
# 123
# Python 3.600000 123

# %%
name = input("Enter your name: ")
print("Hello " + name)
# Out:
# Enter your name: Akkarapon
# Hello Akkarapon

# %%
a = input("Input A : ")
b = input("Input B : ")
c = a + b
print(c)
# Out:
# Input A : 1
# Input B : 3
# 13

# %%
a = int(input("Input A : "))
b = int(input("Input B : "))
c = a + b
print("a + b = %d" % (a + b))
# Out:
# Input A : 1
# Input B : 3
# a + b = 4

# %%
type("16")
# Out:
# str

# %%
type(str(16))
# Out:
# str

# %%
a=[60.8,"26",26,2*2,'2*2',2*2.5,True,False]

for i in range(len(a)):
  print(a[i],"     คือ    ",type(a[i]))
# Out:
# 60.8      คือ     <class 'float'>
# 26      คือ     <class 'str'>
# 26      คือ     <class 'int'>
# 4      คือ     <class 'int'>
# 2*2      คือ     <class 'str'>
# 5.0      คือ     <class 'float'>
# True      คือ     <class 'bool'>
# False      คือ     <class 'bool'>

# %%
name= "Akkarapon Phikulsri"
age = "19"
weigth = "51"
height = "170"

print("\\My name is "+ name+ " \\")
print("\"I'm", age, "years old\"")
print("\'I weigth", weigth, "kg\'")
print("\"\'I height", height, "cm.\'\"")
# Out:
# \My name is Akkarapon Phikulsri \
# "I'm 19 years old"
# 'I weigth 51 kg'
# "'I height 170 cm.'"
